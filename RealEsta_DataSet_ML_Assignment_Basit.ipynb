# %% [markdown]
# ### Real Estate Data Set

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
rdata = pd.read_csv("Real estate.csv")
rdata.info()
rdata.isnull().sum()
rdata.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB
# np.int64(0)

# %%
rdata = redata.drop("No", axis=1)
X = rdata.drop("Y house price of unit area", axis=1)
y = rdata["Y house price of unit area"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

from sklearn.metrics import r2_score
print("R2 Score:", r2_score(y_test, predictions))

plt.scatter(y_test, predictions)
plt.plot(y_test, y_test, color='red')
plt.show()
# Out:
# R2 Score: 0.63241659593618
